# %% [markdown]
# ## 🤗 Hugging Face Lab
# Use Hugging Face models for NLP tasks such as sentiment analysis, text classification, or summarization.

# %%
# Example: Sentiment Analysis using Hugging Face Transformers
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
result = classifier("The product quality is excellent!")
print(result)
